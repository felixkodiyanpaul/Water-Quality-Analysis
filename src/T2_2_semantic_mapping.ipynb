# %%
import subprocess, sys
subprocess.run([sys.executable, "-m", "pip", "install", "dbrepo==1.13.3"], 
               capture_output=True)

import importlib
print("dbrepo installed:", importlib.util.find_spec("dbrepo") is not None)
# Out:
# dbrepo installed: True

# %%
from dbrepo.RestClient import RestClient
import os

os.environ["DBREPO_PASSWORD"] = input("Enter your DBRepo password: ")

client = RestClient(
    endpoint="https://test.dbrepo.tuwien.ac.at",
    username="12534814",
    password=os.environ.get("DBREPO_PASSWORD")
)

print("Logged in as:", client.whoami())
# Out:
# 12534814
# Logged in as: 12534814

# %%
# T2.2 - Complete Ontology Mapping Table
# Ontologies used:
# - ENVO (Environment Ontology): environmental features, locations, water bodies
# - PATO (Phenotype and Trait Ontology): measurable physical/chemical qualities
# - CHEBI (Chemical Entities of Biological Interest): chemical compounds and pollutants
# Justification: ENVO is the domain-standard ontology for environmental features.
# PATO is used for measurable physical/chemical qualities such as temperature and pH.
# CHEBI provides precise internationally recognised identifiers for all chemical
# compounds including nutrients, heavy metals, and organic pollutants.

mappings = [
    # table, column, ontology, concept_uri, label

    # === lake ===
    ("lake", "lake_name",    "ENVO", "http://purl.obolibrary.org/obo/ENVO_00000020", "lake"),
    ("lake", "region",       "ENVO", "http://purl.obolibrary.org/obo/ENVO_00000008", "geographic region"),

    # === sampling_station ===
    ("sampling_station", "station_code", "ENVO", "http://purl.obolibrary.org/obo/ENVO_01001710", "environmental monitoring station"),
    ("sampling_station", "station_name", "ENVO", "http://purl.obolibrary.org/obo/ENVO_01001710", "environmental monitoring station"),
    ("sampling_station", "coord_x",      "ENVO", "http://purl.obolibrary.org/obo/ENVO_01001314", "geographic coordinate"),
    ("sampling_station", "coord_y",      "ENVO", "http://purl.obolibrary.org/obo/ENVO_01001314", "geographic coordinate"),

    # === sampling_event ===
    ("sampling_event", "sampled_on", "PATO", "http://purl.obolibrary.org/obo/PATO_0000165", "time point"),

    # === Core water quality ===
    ("water_quality_measurement", "water_temperature_c",       "PATO",  "http://purl.obolibrary.org/obo/PATO_0000146", "temperature"),
    ("water_quality_measurement", "suspended_solids_mg_l",     "ENVO",  "http://purl.obolibrary.org/obo/ENVO_01001640", "suspended solid"),
    ("water_quality_measurement", "alkalinity_mmol_l",         "PATO",  "http://purl.obolibrary.org/obo/PATO_0001842",  "alkalinity"),
    ("water_quality_measurement", "dissolved_oxygen_mg_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_25369",   "dissolved oxygen"),
    ("water_quality_measurement", "ph",                        "PATO",  "http://purl.obolibrary.org/obo/PATO_0001842",  "pH"),
    ("water_quality_measurement", "transparency_m",            "PATO",  "http://purl.obolibrary.org/obo/PATO_0000161",  "transparency"),
    ("water_quality_measurement", "conductivity_us_cm",        "PATO",  "http://purl.obolibrary.org/obo/PATO_0001757",  "electrical conductivity"),
    ("water_quality_measurement", "bod5_mg_l",                 "ENVO",  "http://purl.obolibrary.org/obo/ENVO_01001551", "biochemical oxygen demand"),
    ("water_quality_measurement", "ammonium_nitrogen_mg_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_28938",   "ammonium"),
    ("water_quality_measurement", "nitrite_nitrogen_mg_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_16301",   "nitrite"),
    ("water_quality_measurement", "nitrate_nitrogen_mg_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_17632",   "nitrate"),
    ("water_quality_measurement", "mineral_nitrogen_mg_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_25555",   "nitrogen"),
    ("water_quality_measurement", "total_nitrogen_mg_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_25555",   "nitrogen"),
    ("water_quality_measurement", "phosphate_phosphorus_mg_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_18367",   "phosphate"),
    ("water_quality_measurement", "total_phosphorus_mg_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_26082",   "phosphorus"),
    ("water_quality_measurement", "carbon_mg_l",               "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27594",   "carbon"),
    ("water_quality_measurement", "chlorophyll_a_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_18230",   "chlorophyll a"),
    ("water_quality_measurement", "calcium_carbonate_mg_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_3311",    "calcium carbonate"),

    # === Heavy metals ===
    ("water_quality_measurement", "mercury_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_33390", "mercury"),
    ("water_quality_measurement", "cadmium_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_22977", "cadmium"),
    ("water_quality_measurement", "nickel_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_28112", "nickel"),
    ("water_quality_measurement", "lead_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_25016", "lead"),
    ("water_quality_measurement", "copper_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_28694", "copper"),
    ("water_quality_measurement", "chromium_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_23337", "chromium"),
    ("water_quality_measurement", "vanadium_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_33341", "vanadium"),
    ("water_quality_measurement", "aluminium_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_28984", "aluminium"),
    ("water_quality_measurement", "tin_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_33302", "tin"),
    ("water_quality_measurement", "arsenic_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_22984", "arsenic"),
    ("water_quality_measurement", "zinc_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_29109", "zinc"),

    # === PAHs ===
    ("water_quality_measurement", "anthracene_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_35391", "anthracene"),
    ("water_quality_measurement", "fluoranthene_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34545", "fluoranthene"),
    ("water_quality_measurement", "naphthalene_ug_l",         "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_16482", "naphthalene"),
    ("water_quality_measurement", "benzo_a_pyrene_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34696", "benzo[a]pyrene"),
    ("water_quality_measurement", "benzo_b_fluoranthene_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34699", "benzo[b]fluoranthene"),
    ("water_quality_measurement", "benzo_k_fluoranthene_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34700", "benzo[k]fluoranthene"),
    ("water_quality_measurement", "benzo_ghi_perylene_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34698", "benzo[ghi]perylene"),
    ("water_quality_measurement", "indeno_123cd_pyrene_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34706", "indeno[1,2,3-cd]pyrene"),

    # === Phenols ===
    ("water_quality_measurement", "p4_n_nonylphenol_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34440", "4-nonylphenol"),
    ("water_quality_measurement", "p4_n_octylphenol_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34013", "4-octylphenol"),
    ("water_quality_measurement", "nonylphenol_branched_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34440", "nonylphenol branched"),
    ("water_quality_measurement", "p4_tert_octylphenol_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34013", "4-tert-octylphenol"),
    ("water_quality_measurement", "nonylphenols_total_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34440", "nonylphenols"),
    ("water_quality_measurement", "pentachlorophenol_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_8062",  "pentachlorophenol"),

    # === Chlorinated solvents ===
    ("water_quality_measurement", "benzene_ug_l",              "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_16716", "benzene"),
    ("water_quality_measurement", "p12_dichloroethane_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27789", "1,2-dichloroethane"),
    ("water_quality_measurement", "p123_trichlorobenzene_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27950", "1,2,3-trichlorobenzene"),
    ("water_quality_measurement", "p124_trichlorobenzene_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27950", "1,2,4-trichlorobenzene"),
    ("water_quality_measurement", "hexachlorobutadiene_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34590", "hexachlorobutadiene"),
    ("water_quality_measurement", "trichloroethylene_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27562", "trichloroethylene"),
    ("water_quality_measurement", "tetrachloromethane_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_27385", "tetrachloromethane"),
    ("water_quality_measurement", "dichloromethane_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_15767", "dichloromethane"),
    ("water_quality_measurement", "tetrachloroethylene_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_17300", "tetrachloroethylene"),
    ("water_quality_measurement", "trichloromethane_ug_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_35255", "trichloromethane"),

    # === Organochlorine pesticides ===
    ("water_quality_measurement", "aldrin_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_2564",  "aldrin"),
    ("water_quality_measurement", "dieldrin_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34677", "dieldrin"),
    ("water_quality_measurement", "isodrin_ug_l",         "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34686", "isodrin"),
    ("water_quality_measurement", "endrin_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34683", "endrin"),
    ("water_quality_measurement", "alpha_hch_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34551", "alpha-hexachlorocyclohexane"),
    ("water_quality_measurement", "beta_hch_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34552", "beta-hexachlorocyclohexane"),
    ("water_quality_measurement", "gamma_hch_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_17089", "gamma-hexachlorocyclohexane"),
    ("water_quality_measurement", "hexachlorobenzene_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_5692",  "hexachlorobenzene"),
    ("water_quality_measurement", "pentachlorobenzene_ug_l","CHEBI","http://purl.obolibrary.org/obo/CHEBI_34856", "pentachlorobenzene"),
    ("water_quality_measurement", "alpha_endosulfan_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34443", "alpha-endosulfan"),
    ("water_quality_measurement", "beta_endosulfan_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34444", "beta-endosulfan"),
    ("water_quality_measurement", "o_p_ddt_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34511", "o,p-DDT"),
    ("water_quality_measurement", "p_p_ddd_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34509", "p,p-DDD"),
    ("water_quality_measurement", "p_p_ddt_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34511", "p,p-DDT"),
    ("water_quality_measurement", "p_p_dde_ug_l",          "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34510", "p,p-DDE"),

    # === Herbicides & other pesticides ===
    ("water_quality_measurement", "simazine_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_9268",  "simazine"),
    ("water_quality_measurement", "atrazine_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_2696",  "atrazine"),
    ("water_quality_measurement", "diuron_ug_l",         "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34807", "diuron"),
    ("water_quality_measurement", "isoproturon_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_38870", "isoproturon"),
    ("water_quality_measurement", "quinoxyfen_ug_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34934", "quinoxyfen"),
    ("water_quality_measurement", "aclonifen_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34836", "aclonifen"),
    ("water_quality_measurement", "cybutryne_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34900", "cybutryne"),
    ("water_quality_measurement", "terbutryn_ug_l",      "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34901", "terbutryn"),
    ("water_quality_measurement", "chlorpyrifos_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34578", "chlorpyrifos"),
    ("water_quality_measurement", "chlorfenvinphos_ug_l","CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34566", "chlorfenvinphos"),
    ("water_quality_measurement", "trifluralin_ug_l",    "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_9400",  "trifluralin"),
    ("water_quality_measurement", "heptachlor_ug_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_5689",  "heptachlor"),
    ("water_quality_measurement", "heptachlor_epoxide_ug_l","CHEBI","http://purl.obolibrary.org/obo/CHEBI_34680","heptachlor epoxide"),
    ("water_quality_measurement", "tributyltin_cation_ug_l","CHEBI","http://purl.obolibrary.org/obo/CHEBI_36731","tributyltin cation"),
    ("water_quality_measurement", "dehp_ug_l",           "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_17747", "bis(2-ethylhexyl) phthalate"),
    ("water_quality_measurement", "alachlor_ug_l",       "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_2455",  "alachlor"),
    ("water_quality_measurement", "bifenox_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34852", "bifenox"),
    ("water_quality_measurement", "cypermethrin_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34634", "cypermethrin"),
    ("water_quality_measurement", "dichlorvos_ug_l",     "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34690", "dichlorvos"),
    ("water_quality_measurement", "dicofol_ug_l",        "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34673", "dicofol"),
    ("water_quality_measurement", "pfos_ug_l",           "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34924", "perfluorooctanesulfonate"),

    # === BDEs ===
    ("water_quality_measurement", "bde_28_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34819", "BDE-28"),
    ("water_quality_measurement", "bde_47_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34820", "BDE-47"),
    ("water_quality_measurement", "bde_85_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34821", "BDE-85"),
    ("water_quality_measurement", "bde_99_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34822", "BDE-99"),
    ("water_quality_measurement", "bde_100_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34823", "BDE-100"),
    ("water_quality_measurement", "bde_153_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34824", "BDE-153"),
    ("water_quality_measurement", "bde_154_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34825", "BDE-154"),

    # === PCBs ===
    ("water_quality_measurement", "pcb_28_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34819", "PCB-28"),
    ("water_quality_measurement", "pcb_52_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34820", "PCB-52"),
    ("water_quality_measurement", "pcb_101_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34821", "PCB-101"),
    ("water_quality_measurement", "pcb_118_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34822", "PCB-118"),
    ("water_quality_measurement", "pcb_138_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34823", "PCB-138"),
    ("water_quality_measurement", "pcb_153_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34824", "PCB-153"),
    ("water_quality_measurement", "pcb_180_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34825", "PCB-180"),

    # === Octylphenol ethoxylates ===
    ("water_quality_measurement", "p4_t_octylphenol_diethoxylate_ug_l",   "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34013", "4-tert-octylphenol diethoxylate"),
    ("water_quality_measurement", "p4_t_octylphenol_monoethoxylate_ug_l", "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34013", "4-tert-octylphenol monoethoxylate"),
    ("water_quality_measurement", "p4_t_octylphenol_triethoxylate_ug_l",  "CHEBI", "http://purl.obolibrary.org/obo/CHEBI_34013", "4-tert-octylphenol triethoxylate"),
]

print(f"Total mappings ready: {len(mappings)}")
# Out:
# Total mappings ready: 113

# %%
DATABASE_ID = "13457a52-37f9-48d4-a078-6865e8d35981"
tables = client.get_tables(database_id=DATABASE_ID)
table_lookup = {}
for table in tables:
    full = client.get_table(database_id=DATABASE_ID, table_id=table.id)
    table_lookup[table.name] = {
        "table_id": table.id,
        "columns": {col.name: col.id for col in full.columns}
    }
print("Tables loaded:", list(table_lookup.keys()))
# Out:
# Tables loaded: ['water_quality_measurement', 'sampling_event', 'sampling_station', 'lake']

# %%
# Get all column IDs for all tables
table_lookup = {}
for table in tables:
    full = client.get_table(
        database_id=DATABASE_ID, 
        table_id=table.id
    )
    table_lookup[table.name] = {
        "table_id": table.id,
        "columns": {col.name: col.id for col in full.columns}
    }
    print(f"\n{table.name} (id={table.id})")
    for col in full.columns:
        print(f"  {col.name}: {col.id}")
# Out:
# water_quality_measurement (id=0b680301-8907-4cad-af74-a345489adf5c)
#   measurement_id: 5a6ae254-67de-4681-98a9-955e4b3dad8f
#   vandens_temp: 364a1444-4a57-47a9-bd49-6c4a5f476dff
#   suspend_medziagos: 00aea0b0-5b3a-41fb-a842-e7d44a044d96
#   sarmingumas: 39b57ed3-68a1-46c1-b3b0-560a48b58bd0
#   deguonis_istirpes: b4362c09-fa4c-4135-81ed-46046a7136f4
#   ph: bc605417-78f3-4ddb-9ab9-43e1b74ac60c
#   skaidrumas: e21ec1f0-4416-4fcf-876b-c0da94af7c29
#   elektr_laidis: 04f34533-2982-413f-be9d-e1558fd226cc
#   biochem_deg_suvartojimas: f4617b1f-7191-4054-9e37-ef5538b49984
#   amonio_azotas: 56b81d24-de93-4cf6-9e63-a67e2f9f633a
#   nitritu_azotas: c61b9a30-789d-4042-ae5d-fd072d2087b5
#   nitratu_azotas: 14705582-c4aa-4307-be03-689242e00095
#   azotas_mineralinis: b3114f70-e73b-4438-a628-56292d936363
#   azotas_bendras: e038b944-8896-4b1b-820e-bb8f1a5495fa
#   fosfatu_fosforas: 49818c57-7057-4cf4-bcf3-f284f98cbaf4
#   fosforas_bendras: 59657311-ba0a-418c-8f92-e897f25cf2da
# ...

# %%
mappings_dbrepo = [
    ("lake", "lake_name",    "http://purl.obolibrary.org/obo/ENVO_00000020"),
    ("lake", "region",       "http://purl.obolibrary.org/obo/ENVO_00000008"),
    ("sampling_station", "station_code", "http://purl.obolibrary.org/obo/ENVO_01001710"),
    ("sampling_station", "station_name", "http://purl.obolibrary.org/obo/ENVO_01001710"),
    ("sampling_station", "coordinates",  "http://purl.obolibrary.org/obo/ENVO_01001314"),
    ("sampling_event", "sampled_on",     "http://purl.obolibrary.org/obo/PATO_0000165"),
    ("water_quality_measurement", "vandens_temp",             "http://purl.obolibrary.org/obo/PATO_0000146"),
    ("water_quality_measurement", "suspend_medziagos",        "http://purl.obolibrary.org/obo/ENVO_01001640"),
    ("water_quality_measurement", "sarmingumas",              "http://purl.obolibrary.org/obo/PATO_0001842"),
    ("water_quality_measurement", "deguonis_istirpes",        "http://purl.obolibrary.org/obo/CHEBI_25369"),
    ("water_quality_measurement", "ph",                       "http://purl.obolibrary.org/obo/PATO_0001842"),
    ("water_quality_measurement", "skaidrumas",               "http://purl.obolibrary.org/obo/PATO_0000161"),
    ("water_quality_measurement", "elektr_laidis",            "http://purl.obolibrary.org/obo/PATO_0001757"),
    ("water_quality_measurement", "biochem_deg_suvartojimas", "http://purl.obolibrary.org/obo/ENVO_01001551"),
    ("water_quality_measurement", "amonio_azotas",            "http://purl.obolibrary.org/obo/CHEBI_28938"),
    ("water_quality_measurement", "nitritu_azotas",           "http://purl.obolibrary.org/obo/CHEBI_16301"),
    ("water_quality_measurement", "nitratu_azotas",           "http://purl.obolibrary.org/obo/CHEBI_17632"),
    ("water_quality_measurement", "azotas_mineralinis",       "http://purl.obolibrary.org/obo/CHEBI_25555"),
    ("water_quality_measurement", "azotas_bendras",           "http://purl.obolibrary.org/obo/CHEBI_25555"),
    ("water_quality_measurement", "fosfatu_fosforas",         "http://purl.obolibrary.org/obo/CHEBI_18367"),
    ("water_quality_measurement", "fosforas_bendras",         "http://purl.obolibrary.org/obo/CHEBI_26082"),
    ("water_quality_measurement", "anglingumas",              "http://purl.obolibrary.org/obo/CHEBI_27594"),
    ("water_quality_measurement", "chlorofilas_a",            "http://purl.obolibrary.org/obo/CHEBI_18230"),
    ("water_quality_measurement", "kalcio_karbonatas",        "http://purl.obolibrary.org/obo/CHEBI_3311"),
    ("water_quality_measurement", "gyvsidabris",              "http://purl.obolibrary.org/obo/CHEBI_33390"),
    ("water_quality_measurement", "kadmis",                   "http://purl.obolibrary.org/obo/CHEBI_22977"),
    ("water_quality_measurement", "nikelis",                  "http://purl.obolibrary.org/obo/CHEBI_28112"),
    ("water_quality_measurement", "svinas",                   "http://purl.obolibrary.org/obo/CHEBI_25016"),
    ("water_quality_measurement", "varis",                    "http://purl.obolibrary.org/obo/CHEBI_28694"),
    ("water_quality_measurement", "chromas",                  "http://purl.obolibrary.org/obo/CHEBI_23337"),
    ("water_quality_measurement", "vanadis",                  "http://purl.obolibrary.org/obo/CHEBI_33341"),
    ("water_quality_measurement", "aliuminis",                "http://purl.obolibrary.org/obo/CHEBI_28984"),
    ("water_quality_measurement", "alavas",                   "http://purl.obolibrary.org/obo/CHEBI_33302"),
    ("water_quality_measurement", "arsenas",                  "http://purl.obolibrary.org/obo/CHEBI_22984"),
    ("water_quality_measurement", "cinkas",                   "http://purl.obolibrary.org/obo/CHEBI_29109"),
    ("water_quality_measurement", "antracenas",               "http://purl.obolibrary.org/obo/CHEBI_35391"),
    ("water_quality_measurement", "fluorantenas",             "http://purl.obolibrary.org/obo/CHEBI_34545"),
    ("water_quality_measurement", "naftalenas",               "http://purl.obolibrary.org/obo/CHEBI_16482"),
    ("water_quality_measurement", "benz_a_pirenas",           "http://purl.obolibrary.org/obo/CHEBI_34696"),
    ("water_quality_measurement", "benz_b_fluorantenas",      "http://purl.obolibrary.org/obo/CHEBI_34699"),
    ("water_quality_measurement", "benz_k_fluorantenas",      "http://purl.obolibrary.org/obo/CHEBI_34700"),
    ("water_quality_measurement", "benz_ghi_perilenas",       "http://purl.obolibrary.org/obo/CHEBI_34698"),
    ("water_quality_measurement", "inden_123_cd_pirenas",     "http://purl.obolibrary.org/obo/CHEBI_34706"),
    ("water_quality_measurement", "p4_n_nonilfenolis",        "http://purl.obolibrary.org/obo/CHEBI_34440"),
    ("water_quality_measurement", "p4_n_oktilfenolis",        "http://purl.obolibrary.org/obo/CHEBI_34013"),
    ("water_quality_measurement", "p4_nonilfenolis_sakot",    "http://purl.obolibrary.org/obo/CHEBI_34440"),
    ("water_quality_measurement", "p4_tert_oktilfenolis",     "http://purl.obolibrary.org/obo/CHEBI_34013"),
    ("water_quality_measurement", "nonilfenoliai",            "http://purl.obolibrary.org/obo/CHEBI_34440"),
    ("water_quality_measurement", "pentachlorfenolis",        "http://purl.obolibrary.org/obo/CHEBI_8062"),
    ("water_quality_measurement", "benzenas",                 "http://purl.obolibrary.org/obo/CHEBI_16716"),
    ("water_quality_measurement", "p12_dichloretanas",        "http://purl.obolibrary.org/obo/CHEBI_27789"),
    ("water_quality_measurement", "p123_trichlorbenzenas",    "http://purl.obolibrary.org/obo/CHEBI_27950"),
    ("water_quality_measurement", "p124_trichlorbenzenas",    "http://purl.obolibrary.org/obo/CHEBI_27950"),
    ("water_quality_measurement", "heksachlorbutadienas",     "http://purl.obolibrary.org/obo/CHEBI_34590"),
    ("water_quality_measurement", "trichloretilenas",         "http://purl.obolibrary.org/obo/CHEBI_27562"),
    ("water_quality_measurement", "tetrachlormetanas",        "http://purl.obolibrary.org/obo/CHEBI_27385"),
    ("water_quality_measurement", "dichlormetanas",           "http://purl.obolibrary.org/obo/CHEBI_15767"),
    ("water_quality_measurement", "tetrachloretilenas",       "http://purl.obolibrary.org/obo/CHEBI_17300"),
    ("water_quality_measurement", "trichlormetanas",          "http://purl.obolibrary.org/obo/CHEBI_35255"),
    ("water_quality_measurement", "aldrinas",                 "http://purl.obolibrary.org/obo/CHEBI_2564"),
    ("water_quality_measurement", "dieldrinas",               "http://purl.obolibrary.org/obo/CHEBI_34677"),
    ("water_quality_measurement", "izodrinas",                "http://purl.obolibrary.org/obo/CHEBI_34686"),
    ("water_quality_measurement", "endrinas",                 "http://purl.obolibrary.org/obo/CHEBI_34683"),
    ("water_quality_measurement", "alfa_heksachlorcikloheksanas", "http://purl.obolibrary.org/obo/CHEBI_34551"),
    ("water_quality_measurement", "beta_heksachlorcikloheksanas", "http://purl.obolibrary.org/obo/CHEBI_34552"),
    ("water_quality_measurement", "gama_heksachlorcikloheksanas", "http://purl.obolibrary.org/obo/CHEBI_17089"),
    ("water_quality_measurement", "heksachlorbenzenas",       "http://purl.obolibrary.org/obo/CHEBI_5692"),
    ("water_quality_measurement", "pentachlorbenzenas",       "http://purl.obolibrary.org/obo/CHEBI_34856"),
    ("water_quality_measurement", "alfa_endosulfanas",        "http://purl.obolibrary.org/obo/CHEBI_34443"),
    ("water_quality_measurement", "beta_endosulfanas",        "http://purl.obolibrary.org/obo/CHEBI_34444"),
    ("water_quality_measurement", "o_p_ddt",                  "http://purl.obolibrary.org/obo/CHEBI_34511"),
    ("water_quality_measurement", "p_p_ddd",                  "http://purl.obolibrary.org/obo/CHEBI_34509"),
    ("water_quality_measurement", "p_p_ddt",                  "http://purl.obolibrary.org/obo/CHEBI_34511"),
    ("water_quality_measurement", "p_p_dde",                  "http://purl.obolibrary.org/obo/CHEBI_34510"),
    ("water_quality_measurement", "simazinas",                "http://purl.obolibrary.org/obo/CHEBI_9268"),
    ("water_quality_measurement", "atrazinas",                "http://purl.obolibrary.org/obo/CHEBI_2696"),
    ("water_quality_measurement", "diuronas",                 "http://purl.obolibrary.org/obo/CHEBI_34807"),
    ("water_quality_measurement", "izoproturonas",            "http://purl.obolibrary.org/obo/CHEBI_38870"),
    ("water_quality_measurement", "chinoksifenas",            "http://purl.obolibrary.org/obo/CHEBI_34934"),
    ("water_quality_measurement", "aklonifenas",              "http://purl.obolibrary.org/obo/CHEBI_34836"),
    ("water_quality_measurement", "cibutrinas",               "http://purl.obolibrary.org/obo/CHEBI_34900"),
    ("water_quality_measurement", "terbutrinas",              "http://purl.obolibrary.org/obo/CHEBI_34901"),
    ("water_quality_measurement", "chlorpyrifosas",           "http://purl.obolibrary.org/obo/CHEBI_34578"),
    ("water_quality_measurement", "chlorfenvinfosas",         "http://purl.obolibrary.org/obo/CHEBI_34566"),
    ("water_quality_measurement", "trifluralinas",            "http://purl.obolibrary.org/obo/CHEBI_9400"),
    ("water_quality_measurement", "heptachloras",             "http://purl.obolibrary.org/obo/CHEBI_5689"),
    ("water_quality_measurement", "heptachloro_epoksidas",    "http://purl.obolibrary.org/obo/CHEBI_34680"),
    ("water_quality_measurement", "tributilalavo_katijonas",  "http://purl.obolibrary.org/obo/CHEBI_36731"),
    ("water_quality_measurement", "di2_etilheksilftalatas",   "http://purl.obolibrary.org/obo/CHEBI_17747"),
    ("water_quality_measurement", "bde_28",                   "http://purl.obolibrary.org/obo/CHEBI_34819"),
    ("water_quality_measurement", "bde_47",                   "http://purl.obolibrary.org/obo/CHEBI_34820"),
    ("water_quality_measurement", "bde_85",                   "http://purl.obolibrary.org/obo/CHEBI_34821"),
    ("water_quality_measurement", "bde_99",                   "http://purl.obolibrary.org/obo/CHEBI_34822"),
    ("water_quality_measurement", "bde_100",                  "http://purl.obolibrary.org/obo/CHEBI_34823"),
    ("water_quality_measurement", "bde_153",                  "http://purl.obolibrary.org/obo/CHEBI_34824"),
    ("water_quality_measurement", "bde_154",                  "http://purl.obolibrary.org/obo/CHEBI_34825"),
    ("water_quality_measurement", "pcb_28",                   "http://purl.obolibrary.org/obo/CHEBI_34819"),
    ("water_quality_measurement", "pcb_52",                   "http://purl.obolibrary.org/obo/CHEBI_34820"),
    ("water_quality_measurement", "pcb_101",                  "http://purl.obolibrary.org/obo/CHEBI_34821"),
    ("water_quality_measurement", "pcb_118",                  "http://purl.obolibrary.org/obo/CHEBI_34822"),
    ("water_quality_measurement", "pcb_138",                  "http://purl.obolibrary.org/obo/CHEBI_34823"),
    ("water_quality_measurement", "pcb_153",                  "http://purl.obolibrary.org/obo/CHEBI_34824"),
    ("water_quality_measurement", "pcb_180",                  "http://purl.obolibrary.org/obo/CHEBI_34825"),
    ("water_quality_measurement", "pfos",                     "http://purl.obolibrary.org/obo/CHEBI_34924"),
    ("water_quality_measurement", "dikofolis",                "http://purl.obolibrary.org/obo/CHEBI_34673"),
    ("water_quality_measurement", "alachloras",               "http://purl.obolibrary.org/obo/CHEBI_2455"),
    ("water_quality_measurement", "bifenoksas",               "http://purl.obolibrary.org/obo/CHEBI_34852"),
    ("water_quality_measurement", "cipermetrinas",            "http://purl.obolibrary.org/obo/CHEBI_34634"),
    ("water_quality_measurement", "dichlorvosas",             "http://purl.obolibrary.org/obo/CHEBI_34690"),
    ("water_quality_measurement", "p4_t_oktilfenolio_dietoksilatas",   "http://purl.obolibrary.org/obo/CHEBI_34013"),
    ("water_quality_measurement", "p4_t_oktilfenolio_monoetoksilatas", "http://purl.obolibrary.org/obo/CHEBI_34013"),
    ("water_quality_measurement", "p4_t_oktilfenolio_trietoksilatas",  "http://purl.obolibrary.org/obo/CHEBI_34013"),
]

# %%
import requests

BASE_URL = "https://test.dbrepo.tuwien.ac.at"
username = "12534814"
password = os.environ.get("DBREPO_PASSWORD")

success = 0
skipped = 0
errors = 0

for table_name, col_name, concept_uri in mappings_dbrepo:
    if table_name not in table_lookup:
        print(f"⚠ Table not found: {table_name}")
        skipped += 1
        continue
    if col_name not in table_lookup[table_name]["columns"]:
        print(f"⚠ Column not found: {table_name}.{col_name}")
        skipped += 1
        continue

    table_id  = table_lookup[table_name]["table_id"]
    column_id = table_lookup[table_name]["columns"][col_name]
    url = f"{BASE_URL}/api/v1/database/{DATABASE_ID}/table/{table_id}/column/{column_id}"

    response = requests.put(
        url,
        json={"concept_uri": concept_uri},
        auth=(username, password)
    )

    if response.status_code in [200, 202]:
        print(f"✓ {table_name}.{col_name}")
        success += 1
    else:
        print(f"✗ {table_name}.{col_name} → {response.status_code}: {response.text[:100]}")
        errors += 1

print(f"\n=== DONE ===")
print(f"✓ {success} pushed | ⚠ {skipped} skipped | ✗ {errors} errors")
# Out:
# ✓ lake.lake_name
# ✓ lake.region
# ✓ sampling_station.station_code
# ✓ sampling_station.station_name
# ✓ sampling_station.coordinates
# ✓ sampling_event.sampled_on
# ✓ water_quality_measurement.vandens_temp
# ✓ water_quality_measurement.suspend_medziagos
# ✓ water_quality_measurement.sarmingumas
# ✓ water_quality_measurement.deguonis_istirpes
# ✓ water_quality_measurement.ph
# ✓ water_quality_measurement.skaidrumas
# ✓ water_quality_measurement.elektr_laidis
# ✓ water_quality_measurement.biochem_deg_suvartojimas
# ✓ water_quality_measurement.amonio_azotas
# ✓ water_quality_measurement.nitritu_azotas
# ✓ water_quality_measurement.nitratu_azotas
# ✓ water_quality_measurement.azotas_mineralinis
# ✓ water_quality_measurement.azotas_bendras
# ✓ water_quality_measurement.fosfatu_fosforas
# ✓ water_quality_measurement.fosforas_bendras
# ✓ water_quality_measurement.anglingumas
# ✓ water_quality_measurement.chlorofilas_a
# ✓ water_quality_measurement.kalcio_karbonatas
# ...
